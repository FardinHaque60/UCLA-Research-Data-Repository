# %%
using Plots

# %%
x = [0, 2, 2.5, 3, 3.5, 4, 4.5]
# Out:
# 7-element Array{Float64,1}:
#  0.0
#  2.0
#  2.5
#  3.0
#  3.5
#  4.0
#  4.5

# %%
y = [1.5, -0.3, -0.25, -0.2, 0.5, 0.8, 1.3]
# Out:
# 7-element Array{Float64,1}:
#   1.5
#  -0.3
#  -0.25
#  -0.2
#   0.5
#   0.8
#   1.3

# %%
plot(x, y, seriestype = :scatter, title = "Drag Force Scatter Plot", label =
"Drag at 20 convective time units")
xlabel!("Diameters Apart")
ylabel!("Drag Coefficient")
